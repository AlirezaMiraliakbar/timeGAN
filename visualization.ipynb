# %%
from metrics.visualization import visualization, visualization_v2
import pickle

# %%
with open('./generated_data/generated_stock_data.pkl', 'rb') as f:
    gen_data = pickle.load(f)
with open('./data/original.pkl', 'rb') as f:
    ori_data = pickle.load(f)

# %%
gen_data = list(gen_data)
ori_data = list(ori_data)

# %%
visualization(ori_data, gen_data, 'pca')
# Out:
# 3661 covariances are mapped
# 3661 covariances are mapped

# %%
visualization_v2(ori_data, gen_data, 'pca')
